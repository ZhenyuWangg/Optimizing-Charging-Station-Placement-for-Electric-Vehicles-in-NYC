# %% [markdown]
# # APAN 5400 Group 10 DEMO

# %% [markdown]
# # Load data from `API`, and select columns that we needed
# - The `API` have Limitations of `1000` records retrieved at a time, we using while loop to retrieved all the records and appended it to our json file.

# %%
import requests
import json

# API endpoint URL
url = 'https://data.ny.gov/resource/7rrd-248n.json?$select=:*,fuel_type_code,station_name,street_address,city,state,zip,station_phone,status_code,access_days_time,ev_level1_evse_num,ev_level2_evse_num,ev_dc_fast_count,ev_network,ev_connector_types&$limit=1000'

# GET request to the API endpoint URL
response = requests.get(url)

# Extract JSON data from the response
json_data = response.json()

# Retrieve additional pages of data and append to the JSON file
offset = 1000
while len(json_data) % 1000 == 0:
    # Increment the offset parameter to retrieve the next page of data
    next_url = f'https://data.ny.gov/resource/7rrd-248n.json?$select=:*,fuel_type_code,station_name,street_address,city,state,zip,station_phone,status_code,access_days_time,ev_level1_evse_num,ev_level2_evse_num,ev_dc_fast_count,ev_network,ev_connector_types&$limit=1000&$offset={offset}'
    next_response = requests.get(next_url)
    next_json_data = next_response.json()
    json_data.extend(next_json_data)
    offset += 1000

# Write the JSON data to a file
with open('EV_Charging_Station.json', 'w') as f:
    json.dump(json_data, f)

# %%
# Load the JSON data from the file
with open('EV_Charging_Station.json', 'r') as f:
    json_data = json.load(f)

# Check the number of records in the JSON data
num_records = len(json_data)
print(f'Number of records: {num_records}')
# Out:
# Number of records: 3314

# %%
json_data[0:3]
# Out:
# [{':id': 'row-ue73_sg9i~33wf',
#   ':created_at': '2023-04-23T19:00:49.547Z',
#   ':updated_at': '2023-04-23T19:00:56.553Z',
#   ':version': 'rv-bdde.dq6e-vhdt',
#   'fuel_type_code': 'ELEC',
#   'station_name': 'Turner Parking Ramp',
#   'street_address': '1 Perkins Dr.',
#   'city': 'Buffalo',
#   'state': 'NY',
#   'zip': '14202',
#   'station_phone': '866-816-7584',
#   'status_code': 'E',
#   'ev_level2_evse_num': '4.0',
#   'ev_network': 'EV Connect',
#   'ev_connector_types': 'J1772'},
#  {':id': 'row-dzf9_3wms.mpyj',
#   ':created_at': '2023-04-23T19:00:49.547Z',
#   ':updated_at': '2023-04-23T19:00:56.553Z',
#   ':version': 'rv-qa9t~rwqh.xhbk',
#   'fuel_type_code': 'ELEC',
#   'station_name': 'Niagara Power Vista',
#   'street_address': '5777 Lewiston Rd',
#   'city': 'Lewiston',
#   'state': 'NY',
#   'zip': '14092',
#   'status_code': 'E',
#   'access_days_time': '24 hours daily',
#   'ev_level2_evse_num': '6.0',
#   'ev_network': 'Non-Networked',
#   'ev_connector_types': 'J1772'},
#  {':id': 'row-p2f5~263m-viei',
#   ':created_at': '2023-04-23T19:00:49.547Z',
#   ':updated_at': '2023-04-23T19:00:56.553Z',
#   ':version': 'rv-83ri~4pwg_hxbi',
#   'fuel_type_code': 'ELEC',
#   'station_name': 'Marshall & Sons',
#   'street_address': '701 Montauk Highway',
#   'city': 'Montauk',
#   'state': 'NY',
#   'zip': '11954',
#   'station_phone': '866-816-7584',
#   'status_code': 'E',
#   'ev_level2_evse_num': '4.0',
#   'ev_network': 'EV Connect',
#   'ev_connector_types': 'J1772'}]

# %% [markdown]
# # Connect to MongoDB

# %%
from pymongo import MongoClient

# Creating a MongoDB client and connecting to the database
client = MongoClient('localhost',27017) ## or MongoClient("localhost:27017")
db = client.apan5400

# %% [markdown]
# # Create MongoDB Collection from JSON file

# %%
with open('EV_Charging_Station.json', 'r') as f:
    data = json.load(f)
    
# Create a collection and insert the data
collection = db['APAN5400_Group_Demo']
collection.drop()
collection = db['APAN5400_Group_Demo']
collection.insert_many(data)

# Find a random document
collection.find_one()
# Out:
# {'_id': ObjectId('644991cd73091b5346905dcb'),
#  ':id': 'row-ue73_sg9i~33wf',
#  ':created_at': '2023-04-23T19:00:49.547Z',
#  ':updated_at': '2023-04-23T19:00:56.553Z',
#  ':version': 'rv-bdde.dq6e-vhdt',
#  'fuel_type_code': 'ELEC',
#  'station_name': 'Turner Parking Ramp',
#  'street_address': '1 Perkins Dr.',
#  'city': 'Buffalo',
#  'state': 'NY',
#  'zip': '14202',
#  'station_phone': '866-816-7584',
#  'status_code': 'E',
#  'ev_level2_evse_num': '4.0',
#  'ev_network': 'EV Connect',
#  'ev_connector_types': 'J1772'}

# %%
# Count documents in the collection
total_docs = collection.count_documents({})
print(f'Number of documents: {total_docs}')
# Out:
# Number of documents: 3314

# %% [markdown]
# # Query example
# - Print the City `Bufflo`, return `address`, `station name` and `phone number`
# - Count the `total number of charging stations` within the `city`

# %%
results = db.APAN5400_Group_Demo.find({"city":'Buffalo'})

for i, doc in  enumerate(results, start=1):
    print(f"{i}.    Address: {doc['street_address']}, {doc['city']},{doc['state']} \n Station name: {doc['station_name']}: {doc['station_phone']}")
# Out:
# 1.    Address: 1 Perkins Dr., Buffalo,NY
#  Station name: Turner Parking Ramp: 866-816-7584
# 2.    Address: 960 Busti Ave, Buffalo,NY
#  Station name: 960 BUSTI 960 BUSTI 1: 888-758-4389
# 3.    Address: Oak St, Buffalo,NY
#  Station name: ERIE COUNTY ECC STATION 1: 888-758-4389
# 4.    Address: 683 Northland Ave, Buffalo,NY
#  Station name: NORTHLAND 2: 888-758-4389
# 5.    Address: 1300 Elmwood Ave., Buffalo,NY
#  Station name: BUFFALO STATE EV STATION 1: 888-758-4389
# 6.    Address: 1615 Amherst Manor Dr, Buffalo,NY
#  Station name: NORTHTOWN CENTE STATION 2: 888-758-4389
# 7.    Address: 1138 Hertel Ave, Buffalo,NY
#  Station name: Tringali's: 866-816-7584
# 8.    Address: 589 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 589ELLICOTT3 CS: 888-758-4389
# 9.    Address: 1197 Niagara Street, Buffalo,NY
#  Station name: Rich Products: 866-816-7584
# 10.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 7: 888-758-4389
# 11.    Address: BRL Parking Lot 3rd from Building  1 South St, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL 5: 888-758-4389
# 12.    Address: 1 Flint rd, Buffalo,NY
#  Station name: NATIONAL GRID COMFORT INN: 888-758-4389
# 13.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 3: 888-758-4389
# 14.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 9: 888-758-4389
# 15.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 13: 888-758-4389
# 16.    Address: 589 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 589 ELLICOTT 6: 888-758-4389
# 17.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 8: 888-758-4389
# 18.    Address: 4891 Transit Rd, Buffalo,NY
#  Station name: LIA HONDA SHOP1: 888-758-4389
# 19.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 4: 888-758-4389
# 20.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 6: 888-758-4389
# 21.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 3: 888-758-4389
# 22.    Address: 2157 Main St, Buffalo,NY
#  Station name: Associate's Lot: 866-816-7584
# 23.    Address: 1678 Hertel Ave, Buffalo,NY
#  Station name: LEX COOP EAST STATION: 888-758-4389
# 24.    Address: 1277 Delaware Ave, Buffalo,NY
#  Station name: MONTANTE SOLAR STATION 5: 888-758-4389
# 25.    Address: BRL Covered Lot, dual charger 1 South Street, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL 2: 888-758-4389
# 26.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 6: 888-758-4389
# 27.    Address: 157 Thorncliff Rd, Buffalo,NY
#  Station name: TONAWANDA YPR POOL PLAZA 3: 888-758-4389
# 28.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 6: 888-758-4389
# 29.    Address: 726 Exchange St, Buffalo,NY
#  Station name: LARKIN726RRAMPP LARKIN 2: 888-758-4389
# 30.    Address: Myrtle St Lot Charger 2 500 Seneca Street, Buffalo,NY
#  Station name: SAVARINO COMPAN 500 SENECA 2: 888-758-4389
# 31.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 14: 888-758-4389
# 32.    Address: 1001 Main Street, Buffalo,NY
#  Station name: CONVENTUS CONVENTUS: 888-758-4389
# 33.    Address: 300 Parkside Ave, Buffalo,NY
#  Station name: NATIONAL GRID BUFFALO ZOO: 888-758-4389
# 34.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 4: 888-758-4389
# 35.    Address: 1111 Fuhrmann Boulevard, Buffalo,NY
#  Station name: NY STATE PARKS HARBOR PARK: 888-758-4389
# 36.    Address: 6205 Main St, Buffalo,NY
#  Station name: ERIE COUNTY STATION ONE: 888-758-4389
# 37.    Address: 6215 Sheridan Dr, Buffalo,NY
#  Station name: FIVE-STAR BANK SOUTH CHARGER: 888-758-4389
# 38.    Address: 1277 Delaware Ave, Buffalo,NY
#  Station name: MONTANTE SOLAR STATION 3: 888-758-4389
# 39.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 5: 888-758-4389
# 40.    Address: 1300 Elmwood Ave, Buffalo,NY
#  Station name: Buffalo State - Cleveland Hall: 716-878-3041
# 41.    Address: Moore Pl, Buffalo,NY
#  Station name: BUFFALO STATE EV STATION 3: 888-758-4389
# 42.    Address: 1277 Delaware Ave, Buffalo,NY
#  Station name: MONTANTE SOLAR STATION 1: 888-758-4389
# 43.    Address: 49 Oak Ct loop, Buffalo,NY
#  Station name: SNYDERPARK OAK CT. 1: 888-758-4389
# 44.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 5: 888-758-4389
# 45.    Address: 4891 Transit Rd, Buffalo,NY
#  Station name: LIA HONDA SHOP2: 888-758-4389
# 46.    Address: 151 Thorncliff Rd, Buffalo,NY
#  Station name: TONAWANDA YPR POOL PLAZA 2: 888-758-4389
# 47.    Address: 275 Alexander Ave, Buffalo,NY
#  Station name: CHEEKTOWAGA ALEXANDER #1: 888-758-4389
# 48.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 2: 888-758-4389
# 49.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 5: 888-758-4389
# 50.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 7: 888-758-4389
# 51.    Address: 2157 Main St Buffalo, Buffalo,NY
#  Station name: Courier's Lot: 866-816-7584
# 52.    Address: 200 Pearl St, Buffalo,NY
#  Station name: Fernbach Parking Ramp: 866-816-7584
# 53.    Address: 1678 Hertel Ave, Buffalo,NY
#  Station name: LEX COOP WEST STATION: 888-758-4389
# 54.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 5: 888-758-4389
# 55.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 5: 888-758-4389
# 56.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 4: 888-758-4389
# 57.    Address: 250 Northwood Dr, Buffalo,NY
#  Station name: COUNTRY CLUB COUNTRY CLUB #1: 888-758-4389
# 58.    Address: Diefendorf Loop, Buffalo,NY
#  Station name: NATIONAL GRID DIEFENDORF HALL: 888-758-4389
# 59.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 6: 888-758-4389
# 60.    Address: 1350 Eggert Rd, Buffalo,NY
#  Station name: 1350 EGGERT RD EGGERT (1): 888-758-4389
# 61.    Address: 275 Alexander Ave, Buffalo,NY
#  Station name: CHEEKTOWAGA ALEXANDER #4: 888-758-4389
# 62.    Address: 2500 Kensington Ave, Buffalo,NY
#  Station name: SDH STATION EV STATION 1: 888-758-4389
# 63.    Address: 726 Exchange St, Buffalo,NY
#  Station name: LARKIN726RRAMPP LARKIN 1: 888-758-4389
# 64.    Address: 1615 Amherst Manor Dr, Buffalo,NY
#  Station name: NORTHTOWN CENTE NORTHTOWN CENTE: 888-758-4389
# 65.    Address: 683 Northland Ave, Buffalo,NY
#  Station name: NORTHLAND 1: 888-758-4389
# 66.    Address: 2232 Delaware Ave, Buffalo,NY
#  Station name: NATIONAL GRID KOHLS BUFFALO: 888-758-4389
# 67.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 4: 888-758-4389
# 68.    Address: 1300 Elmwood Ave, Buffalo,NY
#  Station name: NATIONAL GRID BUFFALO STATE: 888-758-4389
# 69.    Address: 1300 Elmwood Ave, Buffalo,NY
#  Station name: BUFFALO STATE EV STATION 2: 888-758-4389
# 70.    Address: 589 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 589 ELLICOTT 4: 888-758-4389
# 71.    Address: 95 Franklin St, Buffalo,NY
#  Station name: ERIE COUNTY CPF FRANKLIN ST: 888-758-4389
# 72.    Address: 477 Washington St, Buffalo,NY
#  Station name: Mohawk Parking Ramp: 866-816-7584
# 73.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 15: 888-758-4389
# 74.    Address: Myrtle St Lot Charger 3 500 Seneca Street, Buffalo,NY
#  Station name: SAVARINO COMPAN 500 SENECA 3: 888-758-4389
# 75.    Address: 500 Pearl street, Buffalo,NY
#  Station name: 500 PEARL 500 PEARL: 888-758-4389
# 76.    Address: 179 Halbert St, Buffalo,NY
#  Station name: TMD MAIN LOT CT4000-2: 888-758-4389
# 77.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 2: 888-758-4389
# 78.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 3: 888-758-4389
# 79.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 1: 888-758-4389
# 80.    Address: 6215 Sheridan Dr, Buffalo,NY
#  Station name: FIVE-STAR BANK NORTH CHARGER: 888-758-4389
# 81.    Address: 1277 Delaware Ave, Buffalo,NY
#  Station name: MONTANTE SOLAR STATION 4: 888-758-4389
# 82.    Address: 4265 Genesee St, Buffalo,NY
#  Station name: TownePlace Suites - Buffalo Airport: 716-839-1880
# 83.    Address: 147 Thorncliff Rd, Buffalo,NY
#  Station name: TONAWANDA YPR POOL PLAZA 1: 888-758-4389
# 84.    Address: 49 Oak Ct, Buffalo,NY
#  Station name: SNYDERPARK OAK CT. 2: 888-758-4389
# 85.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 2: 888-758-4389
# 86.    Address: BRL Parking Lot, closest to Building 1 South, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL 3: 888-758-4389
# 87.    Address: 4205 Main St, Buffalo,NY
#  Station name: ERIE COUNTY STATION TWO: 888-758-4389
# 88.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 9: 888-758-4389
# 89.    Address: 2157 Main St Buffalo, Buffalo,NY
#  Station name: Physician's Lot: 866-816-7584
# 90.    Address: 1178-1210 Parker blvd, Buffalo,NY
#  Station name: TONAWANDA YPR STATION ONE: 888-758-4389
# 91.    Address: 74 Hamburg St, Buffalo,NY
#  Station name: Gene McCarthy's Old First Ward Brewing Co: 716-855-8948
# 92.    Address: Bissel Hall, Buffalo,NY
#  Station name: NATIONAL GRID BISSEL HALL: 888-758-4389
# 93.    Address: 388 Delaware Ave, Buffalo,NY
#  Station name: Buffalo Club: 518-691-3119
# 94.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 3: 888-758-4389
# 95.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 7: 888-758-4389
# 96.    Address: 39 Scoville Avenue, Buffalo,NY
#  Station name: Bear Metal Works: 866-816-7584
# 97.    Address: BRL Parking Lot 4th from building 1 South Str, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL 6: 888-758-4389
# 98.    Address: 2157 Main St Buffalo, Buffalo,NY
#  Station name: Boiler Sidewalk: 866-816-7584
# 99.    Address: 589 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 589 ELLICOTT 5: 888-758-4389
# 100.    Address: 722 W Delavan Ave, Buffalo,NY
#  Station name: W DELAVAN DELAVAN (1): 888-758-4389
# 101.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 1: 888-758-4389
# 102.    Address: 726 Exchange St, Buffalo,NY
#  Station name: LARKIN726RRAMPP EV ONLY 2: 888-758-4389
# 103.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 3: 888-758-4389
# 104.    Address: 750-770 Hopkins Rd, Buffalo,NY
#  Station name: NORTHTOWN CENTE STATION 1: 888-758-4389
# 105.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 2: 888-758-4389
# 106.    Address: 50 Augspurger Rd, Buffalo,NY
#  Station name: SUNY BUFFALO JACOBS 1: 888-758-4389
# 107.    Address: 589 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 589 ELLICOTT 2: 888-758-4389
# 108.    Address: 185 Hayes Rd, Buffalo,NY
#  Station name: SUNY BUFFALO PARKER 1: 888-758-4389
# 109.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 10: 888-758-4389
# 110.    Address: 1277 Delaware Ave, Buffalo,NY
#  Station name: MONTANTE SOLAR STATION 2: 888-758-4389
# 111.    Address: 5000-5010 Main St, Buffalo,NY
#  Station name: REIKART HOUSE JAZZBOLINE 1: 888-758-4389
# 112.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 10: 888-758-4389
# 113.    Address: 179 Halbert St, Buffalo,NY
#  Station name: TMD MAIN LOT CT4000-1: 888-758-4389
# 114.    Address: 4455 Transit Road, Buffalo,NY
#  Station name: Shops at Main / Transit - Tesla Supercharger: 877-798-3752
# 115.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 12: 888-758-4389
# 116.    Address: BRL Parking Lot 2nd from Building 1 South Str, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL 4: 888-758-4389
# 117.    Address: 221 Pearl St, Buffalo,NY
#  Station name: Main Place Parking Garage: 866-816-7584
# 118.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 1: 888-758-4389
# 119.    Address: BRL Covered Lot, single charger 1 South Stree, Buffalo,NY
#  Station name: SAVARINO COMPAN BRL #1: 888-758-4389
# 120.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 4: 888-758-4389
# 121.    Address: Myrtle St Lot Charger 4 500 Seneca Street, Buffalo,NY
#  Station name: SAVARINO COMPAN 500 SENECA 4: 888-758-4389
# 122.    Address: 3115 Niagara Falls Blvd, Buffalo,NY
#  Station name: NATIONAL GRID KOHLS AMHERST: 888-758-4389
# 123.    Address: 134 High St, Buffalo,NY
#  Station name: 854ELLICOTT 134 HIGH ST 8: 888-758-4389
# 124.    Address: 4200 Genesee St, Buffalo,NY
#  Station name: Buffalo Niagara International Airport: 716-630-6191
# 125.    Address: 726 Exchange St, Buffalo,NY
#  Station name: LARKIN726RRAMPP LARKIN 3: 888-758-4389
# 126.    Address: 854 Ellicott St, Buffalo,NY
#  Station name: 854ELLICOTT 854 ELLICOTT 6: 888-758-4389
# 127.    Address: 50 Elk St, Buffalo,NY
#  Station name: Silos at Elk Street: 866-816-7584
# 128.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 7: 888-758-4389
# 129.    Address: 4871 NY-78, Buffalo,NY
#  Station name: LIA HONDA STATION1: 888-758-4389
# 130.    Address: 1285 Main St, Buffalo,NY
#  Station name: 1285 MAIN 1285 MAIN (1): 888-758-4389
# 131.    Address: 2157 Main St Buffalo, Buffalo,NY
#  Station name: Boiler ER Lot: 866-816-7584
# 132.    Address: 799 Seneca St, Buffalo,NY
#  Station name: 799 SENECA STATION 2: 888-758-4389
# 133.    Address: 726 Exchange St, Buffalo,NY
#  Station name: LARKIN726RRAMPP EV ONLY 1: 888-758-4389
# 134.    Address: 290 South Park Ave, Buffalo,NY
#  Station name: Collision Masters: 866-816-7584

# %%
pipeline = [ 
            {"$match": {"city": "Buffalo"}},
            {"$group": {"_id": None, "count": {"$sum": 1}}}
]

result = db.APAN5400_Group_Demo.aggregate(pipeline)

for doc in result:
    print(f"Total number of charging station {doc['count']}.")
# Out:
# Total number of charging station 134.

# %% [markdown]
# # Find the number of charging station based on `zipcode`

# %%
pipeline = [
            {"$match": {"zip": "14624" } },
            {"$group": {"_id": None, "count": { "$sum": 1 }}}
]

result = db.APAN5400_Group_Demo.aggregate(pipeline)

for doc in result:
    print(f"Total number of charging station {doc['count']}.")
# Out:
# Total number of charging station 5.

# %% [markdown]
# # Create `HTML`

# %%
html = """
<!DOCTYPE html>
<html>
<head>
 <title>EV Charging Station Search Engine</title>
 <style>
  body {
   background-image: url("{{ bg_image_url }}");
   background-size: cover;
  }
  h1 {
   text-align: center;
   color: white;
  }
  form {
   display: flex;
   justify-content: center;
   align-items: center;
   flex-direction: column;
   margin-top: 50px;
  }
  label {
   color: white;
   font-size: 24px;
   margin-bottom: 20px;
  }
  input {
   font-size: 20px;
   padding: 10px;
   width: 400px;
   border-radius: 5px;
   border: none;
   outline: none;
  }
  button {
   font-size: 20px;
   padding: 10px;
   background-color: #007bff;
   color: white;
   border: none;
   border-radius: 5px;
   cursor: pointer;
   transition: background-color 0.2s;
   margin-top: 20px;
  }
  button:hover {
   background-color: #0062cc;
  }
 </style>
</head>
<body>
 <h1>EV Charging Station Search Engine</h1>
 <form method="GET" action="/search">
  <label for="query">Enter search term:</label>
  <input type="text" name="query" id="query" placeholder="Enter search term...">
  <label for="search_type">Search by:</label>
  <select name="search_type" id="search_type">
    <option value="city">City</option>
    <option value="zip">Zip</option>
    <option value="ev_network">EV Network</option>
    <option value="ev_connector_types">Connector Types</option>
  </select>
  <button type="submit">Search</button>
 </form>
</body>
</html>
"""

with open('index.html','w') as f:
    f.write(html)

# %%
html_result = """
<!DOCTYPE html>
<html>
<head>
    <title>Search Result</title>
    <style>
        * {
            font-family: 'Montserrat', sans-serif;
            box-sizing: border-box;
        }

        body {
            background-color: #f5f5f5;
        }

        h1 {
            font-size: 3rem;
            margin: 2rem;
            text-align: center;
            color: #343a40;
        }

        .container {
            max-width: 1400px;
            margin: 0 auto;
            padding: 2rem;
            background-color: #fff;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
        }

        table {
            width: 100%;
            border-collapse: collapse;
            margin-top: 2rem;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }

        th, td {
            border: 1px solid #ccc;
            padding: 1.2rem;
            text-align: center;
        }

        th {
            background-color: #f8f9fa;
            color: #6c757d;
            font-weight: 500;
            text-transform: uppercase;
        }

        tr:hover {
            background-color: #f2f2f2;
        }

        tr:nth-child(even) {
            background-color: #f8f9fa;
        }

        .highlight {
            color: #007bff;
            font-weight: 600;
        }

        @media (max-width: 767px) {
            h1 {
                font-size: 2.5rem;
            }

            table {
                font-size: 0.9rem;
            }
        }
    </style>
    <link href="https://fonts.googleapis.com/css?family=Montserrat:400,500,600&display=swap" rel="stylesheet">
</head>
<body>
    <div class="container">
        <h1>Charging Stations {% if search_type == "city" %}in city{% elif search_type == "zip" %}in zip{% elif search_type == "ev_network" %}in EV network{% elif search_type == "ev_connector_types" %}connector type{% else %}in{% endif %} 
        <span class="highlight">
        {% if search_type == "city" %}{{ result[0]['city'] }}{% endif %}
        {% if search_type == "zip" %}{{ result[0]['zip'] }}{% endif %}
        {% if search_type == "ev_network" %}{{ result[0]['ev_network'] }}{% endif %}
        {% if search_type == "ev_connector_types" %}{{ result[0]['ev_connector_types'] }}{% endif %}
        </span>
        </h1>
        <table>
            <thead>
                <tr>
                    <th>Station Name</th>
                    <th>Address</th>
                    <th>City</th>
                    <th>State</th>
                    <th>Zip</th>
                    <th>Station Phone</th>
                    <th>EV Network</th>
                    <th>Connector Types</th>
                </tr>
            </thead>
            <tbody>
                {% for document in result %}
                    <tr>
                        <td>{{ document['station_name'] }}</td>
                        <td>{{ document['street_address'] }}</td>
                        <td>{{ document['city'] }}</td>
                        <td>{{ document['state'] }}</td>
                        <td>{{ document['zip'] }}</td>
                        <td>{{ document['station_phone'] }}</td>
                        <td>{{ document['ev_network'] }}</td>
                        <td>{{ document['ev_connector_types'] }}</td>
                    </tr>
                {% endfor %}
            </tbody>
        </table>
    </div>
</body>
</html>
"""

with open('index_1.html','w') as f:
    f.write(html_result)

# %% [markdown]
# # Building Flask App

# %%
from flask import Flask, request, render_template, url_for
from pymongo import MongoClient

app = Flask(__name__)
client = MongoClient('localhost', 27017)
db = client['apan5400']
collection = db['APAN5400_Group_Demo']

@app.route('/')
def home():
    bg_image_url = url_for('static', filename='background.jpg')
    return render_template('index.html', bg_image_url=bg_image_url)

@app.route('/search', methods=['GET'])
def search():
    query = request.args.get('query')
    search_type = request.args.get('search_type')

    if search_type == 'zip':
        result = db.APAN5400_Group_Demo.find({"zip": {'$regex': query, '$options': 'i'}})
    elif search_type == 'city':
        result = db.APAN5400_Group_Demo.find({"city": {'$regex': query, '$options': 'i'}})
    elif search_type == 'ev_network':
        result = db.APAN5400_Group_Demo.find({"ev_network": {'$regex': query, '$options': 'i'}})
    elif search_type == 'ev_connector_types':
        result = db.APAN5400_Group_Demo.find({"ev_connector_types": {'$regex': query, '$options': 'i'}})
    else:
        result = db.APAN5400_Group_Demo.find()

    return render_template('index_1.html', result=result, search_type=search_type)

if __name__ == '__main__':
    app.run(port=5001)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [26/Apr/2023 21:08:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 21:09:19] "GET /search?query=new+york&search_type=city HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 21:09:59] "GET /search?query=10023&search_type=zip HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 21:10:16] "GET /search?query=evgo&search_type=ev_network HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 21:10:38] "GET /search?query=Tesla&search_type=ev_connector_types HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 21:17:13] "GET /search?query=Tesla&search_type=ev_connector_types HTTP/1.1" 200 -

# %%
# Drop collection and Close connection
collection.drop()
client.close()
